# %% [markdown]
# <a href="https://colab.research.google.com/github/FilipeSacchetto/Python-Machine-Learning-for-Begginers/blob/master/Regress%C3%A3o_Log%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def funcao_logistica(x):
    return 1 / (1 + np.exp(- x))

# %%
xs = np.linspace(-10, 10, 100)
f_xs = funcao_logistica(xs)

# %%
plt.figure()
plt.plot(xs, f_xs)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %%
def sigmoidal(x, beta0 = 0, beta1 = 1):
    return 1 / (1 + np.exp(-(beta0 + beta1 * x)))

# %%
xbs = np.linspace(-10, 10, 100)
f_xbs_test1 = sigmoidal(xbs, beta0 = 0, beta1 = 1)
f_xbs_test2 = sigmoidal(xbs, beta0 = 5, beta1 = 1)
f_xbs_test3 = sigmoidal(xbs, beta0 = 0, beta1 = 5)

# %%
plt.figure()
plt.plot(xbs, f_xbs_test1, label = 'beta0 = 0, beta1 = 1')
plt.plot(xbs, f_xbs_test2, label = 'beta0 = 5, beta1 = 1')
plt.plot(xbs, f_xbs_test3, label = 'beta0 = 0, beta1 = 5')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()
